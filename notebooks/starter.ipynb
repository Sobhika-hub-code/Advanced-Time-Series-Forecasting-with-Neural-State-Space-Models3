# %% [markdown]
# # Starter notebook for Prophet project
#
# Run the cells to execute the pipeline.

# %%
# !python src/data_gen.py
# !python src/tune_prophet_optuna.py 10
# !python src/sarimax_baseline.py
# !python src/backtest.py
# !python src/evaluate.py
